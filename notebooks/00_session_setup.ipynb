# %% [markdown]
# # 00 — Session Setup
#
# **Run cells top-to-bottom, one at a time. Wait for each to finish before running the next.**
#
# ---
# ### Before running: verify your Colab Secrets
#
# Click the **🔑 key icon** in the left sidebar. You need these secrets with a **blue toggle** (Notebook access ON):
# - `ANTHROPIC_API_KEY` — from console.anthropic.com
# - `HF_TOKEN` — from huggingface.co/settings/tokens
# - `GITHUB_PAT` — from github.com → Settings → Developer settings → Personal access tokens
#
# If any toggle is grey, click it to turn it blue NOW before running anything.
#
# ---
# ### ⚠️ Change your branch name in Cell 3 before running it

# %%
# ── CELL 1: Verify GPU ────────────────────────────────────────────────────────
# Expected: Tesla T4, ~15 GB VRAM
# If you see K80 or < 14 GB: Runtime → Disconnect and delete runtime → reconnect
# !nvidia-smi
import torch
if torch.cuda.is_available():
    name = torch.cuda.get_device_name(0)
    vram = torch.cuda.get_device_properties(0).total_memory / 1e9
    icon = '✅' if vram >= 14 else '⚠️ '
    print(f'\n{icon} GPU: {name}  ({vram:.0f} GB VRAM)')
    if vram < 14:
        print('   You have a K80 (12 GB). Reconnect to get a T4 (16 GB).')
else:
    print('\n❌ No GPU — go to Runtime → Change runtime type → T4 GPU')
# Out:
# Tue Sep 15 18:04:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#
# ✅ GPU: Tesla T4  (16 GB VRAM)

# %%
# ── CELL 2: Mount Google Drive ────────────────────────────────────────────────
# A popup asks for permissions — click Allow on everything (normal Google behaviour).
from google.colab import drive
import os
drive.mount('/content/drive')
if os.path.exists('/content/drive/MyDrive'):
    print('✅ Drive mounted')
else:
    print('❌ Mount failed — run this cell again')
# Out:
# Mounted at /content/drive
# ✅ Drive mounted

# %%
from pathlib import Path

path = Path("/content/project/code/configs/phase1_config.yaml")
text = path.read_text()

text = text.replace(
    'provider:      "openai"',
    'provider:      "anthropic"'
)

text = text.replace(
    'model:         "gpt-4o-mini"',
    'model:         "claude-haiku-4-5"'
)

text = text.replace(
    'provider:    "openai"',
    'provider:    "anthropic"'
)

text = text.replace(
    'model:       "gpt-4o-mini"',
    'model:       "claude-haiku-4-5"'
)

path.write_text(text)

print("Updated phase1_config.yaml back to Anthropic")
# Out:
# Updated phase1_config.yaml back to Anthropic

# %%
# ── CELL 3: Clone or pull the GitHub repo ─────────────────────────────────────
#
# ⚠️  CHANGE BRANCH_NAME BEFORE RUNNING
#     Examples:
#       'advisor_colab_experiments'   ← advisor testing
#       'pair-1/smollm2-1.7b'         ← student pair 1
#       'main'                        ← read-only reference (do not push to main)

import os, subprocess, sys
from google.colab import userdata

BRANCH_NAME = 'pair-1/smollm2-1.7b'          # ← CHANGE THIS
REPO_ORG    = 'Break-Through-Tech'
REPO_NAME   = 'Automation-Anywhere-1B-domain-specific-theme-labeling-via-slm-distillation'
REPO_DIR    = '/content/project'   # repo root

# ── Load PAT ──────────────────────────────────────────────────────────────────
try:
    PAT = userdata.get('GITHUB_PAT')
    assert PAT, 'Secret is empty'
    print(f'✅ GITHUB_PAT loaded ({len(PAT)} chars)')
except Exception as e:
    print(f'❌ GITHUB_PAT: {e}')
    print('   Open 🔑 Secrets → add GITHUB_PAT → toggle Notebook access ON')
    raise SystemExit('Cannot clone without GITHUB_PAT')

REPO_URL = f'https://{PAT}@github.com/{REPO_ORG}/{REPO_NAME}.git'

def git(args, cwd=None, check=True):
    r = subprocess.run(args, cwd=cwd, capture_output=True, text=True)
    if check and r.returncode != 0:
        print(f'❌ git error: {r.stderr.replace(PAT, "***").strip()}')
        raise RuntimeError(' '.join(args))
    return r.stdout.strip()

# ── Clone or pull ──────────────────────────────────────────────────────────────
if not os.path.exists(f'{REPO_DIR}/.git'):
    if os.path.exists(REPO_DIR):
        print('Removing broken directory ...')
        subprocess.run(['rm', '-rf', REPO_DIR])
    print(f'Cloning branch "{BRANCH_NAME}" ...')
    git(['git', 'clone', '-b', BRANCH_NAME, REPO_URL, REPO_DIR])
    print(f'✅ Cloned to {REPO_DIR}')
else:
    print(f'Pulling latest from "{BRANCH_NAME}" ...')
    git(['git', 'checkout', BRANCH_NAME], cwd=REPO_DIR)
    git(['git', 'pull', 'origin', BRANCH_NAME], cwd=REPO_DIR)
    print(f'✅ Up to date')

# ── Auto-detect where main.py lives (repo root or code/ subfolder) ────────────
if os.path.exists(f'{REPO_DIR}/main.py'):
    CODE_DIR = REPO_DIR
elif os.path.exists(f'{REPO_DIR}/code/main.py'):
    CODE_DIR = f'{REPO_DIR}/code'
else:
    CODE_DIR = None
    print('❌ Cannot find main.py — checked repo root and code/ subfolder')
    print(f'   Contents of {REPO_DIR}: {os.listdir(REPO_DIR)}')

if CODE_DIR:
    print(f'✅ Code directory: {CODE_DIR}')
    missing = [f for f in ['requirements.txt', 'requirements_colab.txt']
               if not os.path.exists(f'{CODE_DIR}/{f}')]
    if missing:
        print(f'⚠️  Missing in {CODE_DIR}: {missing}')
        print('   Push these files from your local machine, or run:')
        print('   !git -C /content/project fetch origin')
        print('   !git -C /content/project checkout origin/main -- code/requirements_colab.txt')
    else:
        print('✅ requirements.txt and requirements_colab.txt found')

    os.chdir(CODE_DIR)
    sys.path.insert(0, CODE_DIR)
    # Store CODE_DIR for other cells to use
    os.environ['SLM_CODE_DIR'] = CODE_DIR
    print(f'Working directory: {os.getcwd()}')
# Out:
# ✅ GITHUB_PAT loaded (40 chars)
# Cloning branch "pair-1/smollm2-1.7b" ...
# ✅ Cloned to /content/project
# ✅ Code directory: /content/project/code
# ✅ requirements.txt and requirements_colab.txt found
# Working directory: /content/project/code

# %%
# ── CELL 4: Install dependencies ──────────────────────────────────────────────
# Reads requirements files from the code directory found in Cell 3.
# Takes 3–4 minutes. Normal to see some warnings.
import os, subprocess, sys

CODE_DIR = os.environ.get('SLM_CODE_DIR', '/content/project/code')
print(f'Installing from: {CODE_DIR}')

def pip_install(filename):
    path = f'{CODE_DIR}/{filename}'
    if not os.path.exists(path):
        print(f'❌ {filename} not found at {path}')
        print('   Make sure Cell 3 ran successfully first.')
        return False
    print(f'\nInstalling {filename} ...')
    result = subprocess.run(
        [sys.executable, '-m', 'pip', 'install', '-q', '-r', path],
        capture_output=True, text=True
    )
    tail = (result.stdout + result.stderr).strip().split('\n')
    for line in tail[-5:]:
        if line.strip():
            print(f'  {line}')
    if result.returncode != 0:
        print(f'❌ pip failed for {filename}')
        return False
    print(f'✅ {filename} done')
    return True

ok1 = pip_install('requirements.txt')
ok2 = pip_install('requirements_colab.txt')
print('\n✅ All dependencies installed' if (ok1 and ok2) else '\n⚠️  Check errors above')
# Out:
# Installing from: /content/project/code
#
# Installing requirements.txt ...
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.6 MB/s eta 0:00:00
# ✅ requirements.txt done
#
# Installing requirements_colab.txt ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 111.6 MB/s eta 0:00:00
#   ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
#   gcsfs 2025.12.0 requires fsspec==2025.12.0, but you have fsspec 2025.9.0 which is incompatible.
# ✅ requirements_colab.txt done
#
# ✅ All dependencies installed

# %%
# ── CELL 5: Drive folder structure and HuggingFace cache ─────────────────────
import os

DRIVE_ROOT = '/content/drive/MyDrive/slm-distillation'
for d in [f'{DRIVE_ROOT}/data/raw', f'{DRIVE_ROOT}/data/processed',
          f'{DRIVE_ROOT}/data/checkpoints', f'{DRIVE_ROOT}/outputs',
          f'{DRIVE_ROOT}/hf_cache']:
    os.makedirs(d, exist_ok=True)

os.environ['HF_HOME'] = f'{DRIVE_ROOT}/hf_cache'
os.environ['DRIVE_ROOT'] = DRIVE_ROOT

print(f'✅ Drive folders ready under {DRIVE_ROOT}')
print(f'✅ HF model cache → {os.environ["HF_HOME"]}')
# Out:
# ✅ Drive folders ready under /content/drive/MyDrive/slm-distillation
# ✅ HF model cache → /content/drive/MyDrive/slm-distillation/hf_cache

# %%
# ── CELL 6: Load API keys from Colab Secrets ──────────────────────────────────
import os
from google.colab import userdata

def load_secret(name, required=True):
    try:
        val = userdata.get(name)
        if val:
            os.environ[name] = val
            print(f'  ✅ {name}')
            return True
        print(f'  ⚠️  {name} is empty — {"add value in 🔑 Secrets" if required else "optional"}')
    except Exception:
        print(f'  ❌ {name} not found — {"open 🔑 Secrets and toggle Notebook access ON" if required else "optional"}')
    return not required

print('Loading secrets:')
all_ok = all([
    load_secret('ANTHROPIC_API_KEY', required=True),
    load_secret('HF_TOKEN',          required=True),
    load_secret('OPENAI_API_KEY',    required=False),
])
print('\n✅ Required secrets loaded' if all_ok else '\n❌ Fix missing secrets before running the pipeline')
# Out:
# Loading secrets:
#   ✅ ANTHROPIC_API_KEY
#   ✅ HF_TOKEN
#   ✅ OPENAI_API_KEY
#
# ✅ Required secrets loaded

# %%
# ── CELL 7: Verify everything is ready ───────────────────────────────────────
import os, torch

code_dir  = os.environ.get('SLM_CODE_DIR', '')
drive_ok  = os.path.exists('/content/drive/MyDrive')
gpu_ok    = torch.cuda.is_available()
vram_ok   = gpu_ok and torch.cuda.get_device_properties(0).total_memory > 14e9

checks = [
    ('T4 GPU (≥14 GB VRAM)',   vram_ok),
    ('Drive mounted',          drive_ok),
    ('Code directory found',   bool(code_dir) and os.path.exists(code_dir)),
    ('main.py present',        os.path.exists(f'{code_dir}/main.py') if code_dir else False),
    ('ANTHROPIC_API_KEY set',  'ANTHROPIC_API_KEY' in os.environ),
    ('HF_TOKEN set',           'HF_TOKEN' in os.environ),
    ('HF cache on Drive',      os.environ.get('HF_HOME','').startswith('/content/drive')),
]

print('Setup verification:')
print(f'  Code directory: {code_dir or "NOT SET"}')
print()
all_ok = True
for label, ok in checks:
    print(f'  {"✅" if ok else "❌"} {label}')
    if not ok:
        all_ok = False

print()
print('🚀 Ready! Scroll down to run the pipeline.' if all_ok else
      '⚠️  Fix ❌ items before running the pipeline.')
# Out:
# Setup verification:
#   Code directory: /content/project/code
#
#   ✅ T4 GPU (≥14 GB VRAM)
#   ✅ Drive mounted
#   ✅ Code directory found
#   ✅ main.py present
#   ✅ ANTHROPIC_API_KEY set
#   ✅ HF_TOKEN set
#   ✅ HF cache on Drive
#
# 🚀 Ready! Scroll down to run the pipeline.

# %% [markdown]
# ---
# ## Run the pipeline
#
# Choose one of the cells below. The `$SLM_CODE_DIR` variable is set by Cell 3.

# %%
# ── Full training + evaluation run (~40–60 min on T4) ─────────────────────────
import os
CODE = os.environ.get('SLM_CODE_DIR', '/content/project/code')
# !python "$CODE/main.py" \
    --phase 1 \
    --config "$CODE/configs/phase1_config.yaml" \
    --device_mode colab
# Out:
# 18:06:04 | INFO     | __main__ | [main] Overriding device_mode: local_mps → colab
# 18:06:04 | INFO     | __main__ | [main] Colab mode: drive_root → /content/drive/MyDrive/slm-distillation
# 18:06:05 | INFO     | __main__ | [main] Drive already mounted — skipping drive.mount().
# 18:06:05 | INFO     | __main__ | [main] HF cache → /content/drive/MyDrive/slm-distillation/hf_cache
# 18:06:05 | INFO     | __main__ |
# ============================================================
#   SLM Distillation — Phase 1 | Mode: train
#   Config:      /content/project/code/configs/phase1_config.yaml
#   Device mode: colab
#   Student SLM: HuggingFaceTB/SmolLM2-360M-Instruct
#   Teacher LLM: claude-haiku-4-5
#   Drive root:  /content/drive/MyDrive/slm-distillation
# ============================================================
# 18:06:05 | INFO     | numexpr.utils | NumExpr defaulting to 2 threads.
# 18:06:07 | INFO     | phase1.pipeline | [pipeline] Run ID : 20260915_1806_SmolLM2-360M-Instruct_ep3
# 18:06:07 | INFO     | phase1.pipeline | [pipeline] Outputs → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3
# 18:06:07 | INFO     | phase1.pipeline |
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   STEP 1: Clustering
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 18:06:07 | INFO     | phase1.data.clustering | [clustering] Checkpoint found: /content/drive/MyDrive/slm-distillation/data/processed/bitext_clustered.csv. Skipping.
# 18:06:07 | INFO     | phase1.pipeline |
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   STEP 2: Preprocessing
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 18:06:07 | INFO     | phase1.data.preprocessing | [preprocessing] Grouping 497 tickets into clusters with top-k=10 ...
# 18:06:07 | INFO     | phase1.data.preprocessing | [preprocessing] 21 clusters saved to /content/drive/MyDrive/slm-distillation/data/processed/bitext_grouped.csv
#   Cluster size range: 10–45
#   Top-k=10 tickets per cluster sent to LLM.
# 18:06:07 | INFO     | phase1.data.preprocessing |
# [preprocessing] Sample cluster 8:
#   Ticket 1: problems with a PIN reset...
#   Ticket 2: I cannot recover my account PIN code...
#   Ticket 3: I have got to retrieve my user account PIN...
# 18:06:07 | INFO     | phase1.pipeline |
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   STEP 3: Label generation
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 18:06:07 | INFO     | phase1.labeling.frontier_llm | [labeling] Generating labels for 21 clusters ...
# 18:06:09 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:10 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:11 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:11 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:12 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:13 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:14 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:15 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:16 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:17 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:18 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:18 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:19 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:20 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:21 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:22 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:23 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:23 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:24 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:25 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:26 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:31 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:32 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:32 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:33 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:34 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:35 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:36 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:37 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:38 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:39 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:39 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:40 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:41 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:42 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:43 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:44 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:45 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:46 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:46 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:47 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:48 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:49 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:50 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:51 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:51 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:52 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:53 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:54 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:55 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:56 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:57 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:06:58 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:06:59 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:00 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:00 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:01 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:02 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:03 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:04 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:05 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:05 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:06 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:07 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:08 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:09 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:10 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:11 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:12 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:13 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:14 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:14 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:15 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:16 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:17 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:18 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:19 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:20 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:21 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:21 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:22 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:24 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:25 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:26 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:27 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:28 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:29 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:29 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:30 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:31 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:32 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:33 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:34 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:34 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:35 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:36 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:37 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:38 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:39 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:39 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:40 | INFO     | phase1.labeling.frontier_llm | [labeling] 10/21 clusters done. Checkpoint saved to /content/drive/MyDrive/slm-distillation/data/processed/bitext_labeled.csv
# 18:07:40 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:41 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:42 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:43 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:44 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:44 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:45 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:46 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:47 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:48 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:49 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:49 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:50 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:51 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:52 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:53 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:54 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:55 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:56 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:56 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:57 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:07:58 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:07:59 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:00 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:01 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:02 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:03 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:04 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:05 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:06 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:07 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:08 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:09 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:09 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:10 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:11 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:12 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:13 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:14 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:15 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:16 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:16 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:17 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:18 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:19 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:20 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:21 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:22 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:23 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:24 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:25 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:25 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:26 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:27 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:28 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:29 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:30 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:30 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:31 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:32 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:33 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:34 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:35 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:36 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:37 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:37 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:38 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:39 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:40 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:41 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:42 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:42 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:43 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:44 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:45 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:47 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:48 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:49 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:50 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:51 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:52 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:52 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:53 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:54 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:55 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:56 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:57 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:57 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:08:58 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:08:59 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:00 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:01 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:02 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:02 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:03 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:04 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:05 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:06 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:07 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:08 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:09 | INFO     | phase1.labeling.frontier_llm | [labeling] 20/21 clusters done. Checkpoint saved to /content/drive/MyDrive/slm-distillation/data/processed/bitext_labeled.csv
# 18:09:09 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:09 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:10 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:11 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:12 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:16 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:17 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:18 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:19 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:09:19 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:09:20 | INFO     | phase1.labeling.frontier_llm | [labeling] 21/21 clusters done. Checkpoint saved to /content/drive/MyDrive/slm-distillation/data/processed/bitext_labeled.csv
# 18:09:20 | INFO     | phase1.labeling.frontier_llm | [labeling] All labels saved to /content/drive/MyDrive/slm-distillation/data/processed/bitext_labeled.csv
# 18:09:20 | INFO     | phase1.evaluation.business_eval | [business_eval] Teacher latency records persisted → /content/drive/MyDrive/slm-distillation/data/processed/teacher_latency_records.csv (105 records)
# 18:09:20 | INFO     | phase1.pipeline | [pipeline] Labeled data copied → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/labeled_data.csv
# 18:09:20 | INFO     | phase1.finetuning.trainer | [trainer] HF model cache → /content/drive/MyDrive/slm-distillation/hf_cache
# 18:09:20 | INFO     | phase1.finetuning.trainer | [trainer] Loading HuggingFaceTB/SmolLM2-360M-Instruct in mode=colab ...
# 18:09:32 | INFO     | phase1.finetuning.trainer | [trainer] target_modules 'all-linear' → ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj'] (model: SmolLM2-360M-Instruct)
# /usr/local/lib/python3.13/dist-packages/unsloth/__init__.py:1554: UserWarning: WARNING: Unsloth should be imported before [transformers] to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from ._gpu_init import *
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 18:09:41 | INFO     | datasets | Disabling Tensorflow because USE_TORCH is set
# 18:09:41 | INFO     | datasets | JAX version 0.11.1 available.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 18:09:50 | INFO     | phase1.finetuning.trainer | [trainer] Unsloth detected — using accelerated loading.
# 18:09:52 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/whoami-v2 "HTTP/1.1 200 OK"
# 18:09:52 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:09:52 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:09:52 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:09:52 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 18:09:53 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/whoami-v2 "HTTP/1.1 200 OK"
# ==((====))==  Unsloth 2026.9.4: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# 18:09:53 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/revision/main "HTTP/1.1 200 OK"
# 18:09:53 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/tree/20f9daee9da18936efa03ad4e1361884c60cca0c?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:09:53 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:09:53 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:09:53 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:09:53 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/xet-read-token/20f9daee9da18936efa03ad4e1361884c60cca0c "HTTP/1.1 200 OK"
# 18:09:53 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 200 OK"
# 18:09:53 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/revision/main "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/tree/7c48478c02f84ed89f149b0815cc0216ee831fb0?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:09:54 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:09:54 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/xet-read-token/7c48478c02f84ed89f149b0815cc0216ee831fb0 "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:09:54 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 200 OK"
# 18:09:54 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/revision/main "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/tree/9703344699da71a2bb9f17e575eb918c8f6cb349?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:09:55 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:09:55 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/xet-read-token/9703344699da71a2bb9f17e575eb918c8f6cb349 "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:09:55 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 200 OK"
# 18:09:55 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/revision/main "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/tree/7ec782b7604cd9ea0781c23a4270f031650f5617?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:09:56 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:09:56 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:09:56 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/xet-read-token/7ec782b7604cd9ea0781c23a4270f031650f5617 "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 200 OK"
# 18:09:56 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 200 OK"
# 18:09:57 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:09:57 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:09:57 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/modules.json "HTTP/1.1 404 Not Found"
# 18:09:57 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct "HTTP/1.1 200 OK"
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/constants.py:299: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/constants.py:299: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# 18:10:08 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:10:08 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:10:08 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:10:08 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# Loading weights: 100% 290/290 [00:01<00:00, 211.01it/s]
# 18:10:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:10:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/generation_config.json "HTTP/1.1 200 OK"
# 18:10:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:10:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:10:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:10:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/tokenizer_config.json "HTTP/1.1 200 OK"
# 18:10:10 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 18:10:10 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:10:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# 18:10:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# 18:10:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:10:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:10:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:10:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/tokenizer_config.json "HTTP/1.1 200 OK"
# 18:10:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 18:10:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# Unsloth: HuggingFaceTB/SmolLM2-360M-Instruct had a bad pad_token (<|im_end|>). Using pad_token = <|endoftext|>.
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2026.9.4 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.
# 18:10:21 | INFO     | phase1.finetuning.trainer | [trainer] Model loaded. Trainable params: 8,683,520
# 18:10:21 | INFO     | phase1.pipeline |
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   STEP 4: Building dataset
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 18:10:21 | INFO     | phase1.finetuning.dataset | [dataset] Cluster split — train: 14, val: 3, test: 4
# 18:10:21 | INFO     | phase1.finetuning.dataset | [dataset] train: 70 examples → /content/drive/MyDrive/slm-distillation/data/processed/train.jsonl
# 18:10:21 | INFO     | phase1.finetuning.dataset | [dataset] val: 15 examples → /content/drive/MyDrive/slm-distillation/data/processed/val.jsonl
# 18:10:21 | INFO     | phase1.finetuning.dataset | [dataset] test: 20 examples → /content/drive/MyDrive/slm-distillation/data/processed/test.jsonl
# 18:10:21 | INFO     | phase1.finetuning.dataset | [dataset] Cluster split map saved → /content/drive/MyDrive/slm-distillation/data/processed/cluster_splits.json
# 18:10:21 | INFO     | phase1.pipeline |
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   STEP 5: Fine-tuning
# ...
# 18:14:34 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:35 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:36 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:37 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:38 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:39 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:41 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:42 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:43 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:44 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:45 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:46 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:48 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:49 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:50 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:51 | INFO     | phase1.evaluation.llm_judge | [llm_judge] 20/20 judged.
# 18:14:51 | INFO     | phase1.evaluation.llm_judge | [llm_judge] Judge scores → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/_cache/judge_scores_baseline.csv
# 18:14:51 | INFO     | phase1.evaluation.llm_judge | [llm_judge] LLM metrics (JSON) → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/_cache/llm_baseline.csv
# 18:14:51 | INFO     | phase1.evaluation.llm_judge |
# =======================================================
#   LLM JUDGE SUMMARY — SLM BASELINE (PRE-DISTILLATION)
# =======================================================
#   Faithfulness    : 2.85 / 5
#   Specificity     : 1.95 / 5
#   Equivalence     : 1.80 / 5
#   Composite score:  2.20 / 5
# =======================================================
# 18:14:51 | INFO     | phase1.evaluation.llm_judge | [llm_judge] Running judge on 20 predictions (tag=finetuned, mode=reference) ...
# 18:14:51 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:53 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:54 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:55 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:56 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:14:58 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:14:59 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:00 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:01 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:02 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:03 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:05 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:06 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:07 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:08 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:10 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:11 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:12 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:13 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:15 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:16 | INFO     | phase1.evaluation.llm_judge | [llm_judge] 10/20 judged.
# 18:15:16 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:17 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:18 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:20 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:21 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:23 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:24 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:25 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:26 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:28 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:29 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:30 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:31 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:33 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:34 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:35 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:36 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:37 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:38 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:15:40 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 18:15:41 | INFO     | phase1.evaluation.llm_judge | [llm_judge] 20/20 judged.
# 18:15:41 | INFO     | phase1.evaluation.llm_judge | [llm_judge] Judge scores → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/_cache/judge_scores_finetuned.csv
# 18:15:41 | INFO     | phase1.evaluation.llm_judge | [llm_judge] LLM metrics (JSON) → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/_cache/llm_finetuned.csv
# 18:15:41 | INFO     | phase1.evaluation.llm_judge |
# =======================================================
#   LLM JUDGE SUMMARY — SLM FINE-TUNED (SMOLLM2-360M-INSTRUCT)
# =======================================================
#   Faithfulness    : 3.15 / 5
#   Specificity     : 2.10 / 5
#   Equivalence     : 2.00 / 5
#   Composite score:  2.42 / 5
# =======================================================
# 18:15:41 | INFO     | phase1.pipeline |
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   STEP 9: Business evaluation
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 18:15:41 | INFO     | phase1.evaluation.business_eval | [business_eval] Teacher latency: computed at runtime — 105 API calls, mean 0.84s
# 18:15:41 | INFO     | phase1.evaluation.business_eval | [business_eval] Latency file (teacher) → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/_cache/latency_teacher.csv  (105 records, mean 0.837s)
# 18:15:41 | INFO     | phase1.evaluation.business_eval | [business_eval] Latency file (baseline) → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/_cache/latency_baseline.csv  (20 records, mean 1.839s)
# 18:15:41 | INFO     | phase1.evaluation.business_eval | [business_eval] Latency file (finetuned) → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/_cache/latency_finetuned.csv  (20 records, mean 1.702s)
# 18:15:41 | INFO     | phase1.evaluation.business_eval | [business_eval] Business metrics saved to /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/business_eval.csv
# 18:15:41 | INFO     | phase1.evaluation.business_eval |
# =======================================================
#   BUSINESS EVALUATION SUMMARY
# =======================================================
#   Teacher LLM (claude-haiku-4-5):
#     Mean call latency:   0.84s
#     Total API calls:     105
#     Estimated cost:      $0.0137 USD
#
#   Student SLM (HuggingFaceTB/SmolLM2-360M-Instruct):
#   Model loading time (one-time, not in per-label latency):
#     baseline          : 17.3s
#     finetuned         : 17.4s
#     Baseline inference:  1.839s / label
#     Fine-tuned inference:1.702s / label
#     Inference cost:      ~$0.00 (local/Colab)
#     Speed vs teacher:    0.5x faster
#
# 18:15:41 | INFO     | phase1.evaluation.business_eval |   Fine-tuning time:    0.9 min
# =======================================================
# 18:15:41 | INFO     | phase1.pipeline |
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   STEP 10: Combining results
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 18:15:41 | INFO     | phase1.evaluation.combine | [combine] Labels pivot → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/labels_by_cluster.csv  (105 rows)
# 18:15:41 | INFO     | phase1.evaluation.combine | [combine] Latency pivot → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/latency_by_cluster.csv  (105 rows)
# 18:15:41 | INFO     | phase1.evaluation.combine | [combine] Non-LLM by-cluster pivot → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/nonllm_by_cluster.csv  (20 rows)
# 18:15:41 | INFO     | phase1.evaluation.combine | [combine] LLM judge by-cluster pivot → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/llm_by_cluster.csv  (20 rows)
# 18:15:41 | INFO     | phase1.evaluation.combine | [combine] Non-LLM metrics summary → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/metrics_summary.csv
# 18:15:41 | INFO     | phase1.evaluation.combine |
# =================================================================
#   NON-LLM METRICS SUMMARY (by split)
# =================================================================
# ╭─────────┬───────────┬───────────────────┬────────────────────┬────────────────┬─────────────────┬─────────────────────┬──────────────────────╮
# │ split   │ model     │   cosine_sim_same │   cosine_sim_multi │   rouge_l_same │   rouge_l_multi │   bertscore_f1_same │   bertscore_f1_multi │
# ├─────────┼───────────┼───────────────────┼────────────────────┼────────────────┼─────────────────┼─────────────────────┼──────────────────────┤
# │ train   │ teacher   │          nan      │           nan      │       nan      │        nan      │                 nan │                  nan │
# │ train   │ baseline  │          nan      │           nan      │       nan      │        nan      │                 nan │                  nan │
# │ train   │ finetuned │          nan      │           nan      │       nan      │        nan      │                 nan │                  nan │
# │ val     │ teacher   │          nan      │           nan      │       nan      │        nan      │                 nan │                  nan │
# │ val     │ baseline  │          nan      │           nan      │       nan      │        nan      │                 nan │                  nan │
# │ val     │ finetuned │          nan      │           nan      │       nan      │        nan      │                 nan │                  nan │
# │ test    │ teacher   │            1.0000 │             1.0000 │         1.0000 │          1.0000 │                 nan │                  nan │
# │ test    │ baseline  │            0.4843 │             0.5156 │         0.1469 │          0.1796 │                 nan │                  nan │
# │ test    │ finetuned │            0.5077 │             0.5516 │         0.1823 │          0.2284 │                 nan │                  nan │
# ╰─────────┴───────────┴───────────────────┴────────────────────┴────────────────┴─────────────────┴─────────────────────┴──────────────────────╯
# =================================================================
# 18:15:41 | INFO     | phase1.evaluation.combine | [combine] LLM judge summary → /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation/judge_summary.csv
# 18:15:41 | INFO     | phase1.evaluation.combine |
# =================================================================
#   LLM JUDGE SUMMARY (by split)
# =================================================================
# ╭─────────┬───────────┬───────────────┬────────────────┬───────────────┬─────────────╮
# │ split   │ model     │   equivalence │   faithfulness │   specificity │   composite │
# ├─────────┼───────────┼───────────────┼────────────────┼───────────────┼─────────────┤
# │ train   │ teacher   │      nan      │       nan      │      nan      │    nan      │
# │ train   │ baseline  │      nan      │       nan      │      nan      │    nan      │
# │ train   │ finetuned │      nan      │       nan      │      nan      │    nan      │
# │ val     │ teacher   │      nan      │       nan      │      nan      │    nan      │
# │ val     │ baseline  │      nan      │       nan      │      nan      │    nan      │
# │ val     │ finetuned │      nan      │       nan      │      nan      │    nan      │
# │ test    │ teacher   │        5.0000 │         5.0000 │        5.0000 │      5.0000 │
# │ test    │ baseline  │        1.8000 │         2.8500 │        1.9500 │      2.2000 │
# │ test    │ finetuned │        2.0000 │         3.1500 │        2.1000 │      2.4167 │
# ╰─────────┴───────────┴───────────────┴────────────────┴───────────────┴─────────────╯
# =================================================================
# 18:15:41 | INFO     | phase1.pipeline |
# ============================================================
#   Phase 1 pipeline complete.
#   Results: /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/evaluation
# ============================================================

# %%
test_tickets = """I forgot my account PIN and cannot access my account.
My package was marked delivered but I never received it.
How can I contact customer support?
I need to change the email address linked to my account.
My delivery is three days late and there is no tracking update."""

with open("/content/test_tickets.txt", "w") as f:
    f.write(test_tickets)

print("Saved to /content/test_tickets.txt")
# Out:
# Saved to /content/test_tickets.txt

# %%
test_tickets = """I forgot my account PIN and cannot access my account.
I need to reset my PIN to log back into my account.
My PIN isn't working and I'm locked out of my account."""

with open("/content/test_tickets.txt", "w") as f:
    f.write(test_tickets)

# %%
# ── Live demo mode ────────────────────────────────────────────────────────────
import os
CODE  = os.environ.get('SLM_CODE_DIR', '/content/project/code')
DRIVE = os.environ.get('DRIVE_ROOT', '/content/drive/MyDrive/slm-distillation')

ADAPTER = f'{DRIVE}/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/models/lora_adapter'

# !python "$CODE/main.py" \
    --phase 1 \
    --config "$CODE/configs/phase1_config.yaml" \
    --device_mode colab \
    --mode demo \
    --adapter_dir "$ADAPTER"
# Out:
# 18:43:50 | INFO     | __main__ | [main] Overriding device_mode: local_mps → colab
# 18:43:50 | INFO     | __main__ | [main] Colab mode: drive_root → /content/drive/MyDrive/slm-distillation
# 18:43:50 | INFO     | __main__ | [main] Drive already mounted — skipping drive.mount().
# 18:43:50 | INFO     | __main__ | [main] HF cache → /content/drive/MyDrive/slm-distillation/hf_cache
# 18:43:50 | INFO     | __main__ |
# ============================================================
#   SLM Distillation — Phase 1 | Mode: demo
#   Config:      /content/project/code/configs/phase1_config.yaml
#   Device mode: colab
#   Student SLM: HuggingFaceTB/SmolLM2-360M-Instruct
#   Teacher LLM: claude-haiku-4-5
#   Drive root:  /content/drive/MyDrive/slm-distillation
# ============================================================
# 18:43:50 | INFO     | numexpr.utils | NumExpr defaulting to 2 threads.
# 18:43:57 | WARNING  | torchao | Failed to load /usr/local/lib/python3.13/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.13/dist-packages/torchao/_C_cutlass_90a.abi3.so
# 18:43:57 | WARNING  | torchao | Failed to load /usr/local/lib/python3.13/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.13/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
#
# ====================================================================
#   SLM DISTILLATION — LIVE DEMO
#   Default prompt: P1  |  Top-k: 10  |  Device: colab
#   Judge mode: reference
# ====================================================================
#
# Loading metric tools ...
# 18:43:59 | INFO     | datasets | TensorFlow version 2.20.0 available.
# 18:43:59 | INFO     | datasets | JAX version 0.11.1 available.
# 18:44:02 | INFO     | phase1.evaluation.metrics | [metrics] Loading embedding model: all-mpnet-base-v2
# 18:44:02 | INFO     | sentence_transformers.base.model | No device provided, using cuda:0
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/modules.json "HTTP/1.1 200 OK"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 18:44:02 | INFO     | sentence_transformers.base.model | Loading SentenceTransformer model from sentence-transformers/all-mpnet-base-v2.
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/README.md "HTTP/1.1 200 OK"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/modules.json "HTTP/1.1 200 OK"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/sentence_bert_config.json "HTTP/1.1 200 OK"
# 18:44:02 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/config.json "HTTP/1.1 200 OK"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/config.json "HTTP/1.1 200 OK"
# Loading weights: 100% 199/199 [00:00<00:00, 3344.69it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/video_preprocessor_config.json "HTTP/1.1 404 Not Found"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/tokenizer_config.json "HTTP/1.1 200 OK"
# 18:44:03 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:04 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/config.json "HTTP/1.1 200 OK"
# 18:44:04 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:04 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/config.json "HTTP/1.1 200 OK"
# 18:44:04 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:04 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/tokenizer_config.json "HTTP/1.1 200 OK"
# 18:44:04 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-mpnet-base-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 18:44:04 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-mpnet-base-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:04 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:04 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-mpnet-base-v2/e8c3b32edf5434bc2275fc9bab85f82640a19130/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# 18:44:04 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-mpnet-base-v2 "HTTP/1.1 200 OK"
# 18:44:05 | INFO     | absl | Using default tokenizer.
#   Metric tools ready (6.1s)
# Loading base SLM (SmolLM2-360M-Instruct) ...
# 18:44:05 | INFO     | phase1.finetuning.trainer | [trainer] HF model cache → /content/drive/MyDrive/slm-distillation/hf_cache
# 18:44:05 | INFO     | phase1.finetuning.trainer | [trainer] Loading HuggingFaceTB/SmolLM2-360M-Instruct in mode=colab ...
# 18:44:05 | INFO     | phase1.finetuning.trainer | [trainer] target_modules 'all-linear' → ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj'] (model: SmolLM2-360M-Instruct)
# /usr/local/lib/python3.13/dist-packages/unsloth/__init__.py:1554: UserWarning: WARNING: Unsloth should be imported before [transformers, peft] to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from ._gpu_init import *
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 18:44:10 | INFO     | phase1.finetuning.trainer | [trainer] Unsloth detected — using accelerated loading.
# 18:44:10 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/whoami-v2 "HTTP/1.1 200 OK"
# 18:44:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:10 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 18:44:10 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/whoami-v2 "HTTP/1.1 200 OK"
# ==((====))==  Unsloth 2026.9.4: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# 18:44:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/revision/main "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/tree/20f9daee9da18936efa03ad4e1361884c60cca0c?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/xet-read-token/20f9daee9da18936efa03ad4e1361884c60cca0c "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:44:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 200 OK"
# 18:44:11 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/revision/main "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/tree/7c48478c02f84ed89f149b0815cc0216ee831fb0?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:44:12 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:12 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:12 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/xet-read-token/7c48478c02f84ed89f149b0815cc0216ee831fb0 "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/revision/main "HTTP/1.1 200 OK"
# 18:44:12 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/tree/9703344699da71a2bb9f17e575eb918c8f6cb349?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:44:13 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:13 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:13 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/xet-read-token/9703344699da71a2bb9f17e575eb918c8f6cb349 "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/revision/main "HTTP/1.1 200 OK"
# 18:44:13 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/tree/7ec782b7604cd9ea0781c23a4270f031650f5617?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/xet-read-token/7ec782b7604cd9ea0781c23a4270f031650f5617 "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:14 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/modules.json "HTTP/1.1 404 Not Found"
# 18:44:14 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct "HTTP/1.1 200 OK"
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/constants.py:299: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# 18:44:16 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:16 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:16 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:16 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# Loading weights: 100% 290/290 [00:01<00:00, 226.45it/s]
# 18:44:18 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:18 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/generation_config.json "HTTP/1.1 200 OK"
# 18:44:18 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:18 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:18 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:18 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/tokenizer_config.json "HTTP/1.1 200 OK"
# 18:44:19 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 18:44:19 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:19 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:19 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:19 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:19 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/tokenizer_config.json "HTTP/1.1 200 OK"
# 18:44:19 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 18:44:19 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# Unsloth: HuggingFaceTB/SmolLM2-360M-Instruct had a bad pad_token (<|im_end|>). Using pad_token = <|endoftext|>.
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2026.9.4 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.
# 18:44:26 | INFO     | phase1.finetuning.trainer | [trainer] Model loaded. Trainable params: 8,683,520
#   Base SLM ready  (21.3s)
# Loading fine-tuned SLM from /content/drive/MyDrive/slm-distillation/outputs/20260915_1806_SmolLM2-360M-Instruct_ep3/models/lora_adapter ...
# 18:44:26 | INFO     | phase1.finetuning.trainer | [trainer] HF model cache → /content/drive/MyDrive/slm-distillation/hf_cache
# 18:44:26 | INFO     | phase1.finetuning.trainer | [trainer] Loading HuggingFaceTB/SmolLM2-360M-Instruct in mode=colab ...
# 18:44:26 | INFO     | phase1.finetuning.trainer | [trainer] target_modules 'all-linear' → ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj'] (model: SmolLM2-360M-Instruct)
# 18:44:26 | INFO     | phase1.finetuning.trainer | [trainer] Unsloth detected — using accelerated loading.
# 18:44:27 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/whoami-v2 "HTTP/1.1 200 OK"
# 18:44:27 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:27 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:27 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 18:44:27 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/whoami-v2 "HTTP/1.1 200 OK"
# ==((====))==  Unsloth 2026.9.4: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# 18:44:27 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/revision/main "HTTP/1.1 200 OK"
# 18:44:27 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/tree/20f9daee9da18936efa03ad4e1361884c60cca0c?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:27 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:27 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 200 OK"
# 18:44:27 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:44:27 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/colab/xet-read-token/20f9daee9da18936efa03ad4e1361884c60cca0c "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/README.md "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/colab/resolve/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:28 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/.gitattributes "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/colab/20f9daee9da18936efa03ad4e1361884c60cca0c/config.json "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/revision/main "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/tree/7c48478c02f84ed89f149b0815cc0216ee831fb0?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:44:28 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/repeat/xet-read-token/7c48478c02f84ed89f149b0815cc0216ee831fb0 "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/.gitattributes "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:28 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 200 OK"
# 18:44:28 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/repeat/resolve/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:29 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/README.md "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/repeat/7c48478c02f84ed89f149b0815cc0216ee831fb0/config.json "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/revision/main "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/tree/9703344699da71a2bb9f17e575eb918c8f6cb349?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:44:29 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/vram-16/xet-read-token/9703344699da71a2bb9f17e575eb918c8f6cb349 "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/.gitattributes "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:29 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/README.md "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/vram-16/resolve/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:29 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 200 OK"
# 18:44:29 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/vram-16/9703344699da71a2bb9f17e575eb918c8f6cb349/config.json "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/revision/main "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/tree/7ec782b7604cd9ea0781c23a4270f031650f5617?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/unslothai/1/xet-read-token/7ec782b7604cd9ea0781c23a4270f031650f5617 "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# 18:44:30 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 307 Temporary Redirect"
# 18:44:30 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/unslothai/1/resolve/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:30 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/.gitattributes "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/README.md "HTTP/1.1 200 OK"
# 18:44:30 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unslothai/1/7ec782b7604cd9ea0781c23a4270f031650f5617/config.json "HTTP/1.1 200 OK"
# 18:44:31 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:31 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:31 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/modules.json "HTTP/1.1 404 Not Found"
# 18:44:31 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct "HTTP/1.1 200 OK"
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/constants.py:299: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# 18:44:32 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:32 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:32 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:32 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# Loading weights: 100% 290/290 [00:01<00:00, 230.08it/s]
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/generation_config.json "HTTP/1.1 200 OK"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/tokenizer_config.json "HTTP/1.1 200 OK"
# 18:44:34 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 18:44:34 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/config.json "HTTP/1.1 200 OK"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/HuggingFaceTB/SmolLM2-360M-Instruct/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 18:44:34 | INFO     | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/HuggingFaceTB/SmolLM2-360M-Instruct/a10cc1512eabd3dde888204e902eca88bddb4951/tokenizer_config.json "HTTP/1.1 200 OK"
# 18:44:34 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 18:44:35 | INFO     | httpx | HTTP Request: GET https://huggingface.co/api/models/HuggingFaceTB/SmolLM2-360M-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# Unsloth: HuggingFaceTB/SmolLM2-360M-Instruct had a bad pad_token (<|im_end|>). Using pad_token = <|endoftext|>.
# 18:44:43 | INFO     | phase1.finetuning.trainer | [trainer] Model loaded. Trainable params: 8,683,520
# /usr/local/lib/python3.13/dist-packages/peft/tuners/tuners_utils.py:305: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
#   Fine-tuned SLM ready  (16.9s)
#
# ────────────────────────────────────────────────────────────────────
#   Model loading times (one-time, NOT included in per-label latency):
#     Base SLM:        21.3s
#     Fine-tuned SLM:  16.9s
# ────────────────────────────────────────────────────────────────────
#
# Ready.  Type a ticket file path (one ticket per line) and press Enter.
# Type 'exit' to stop.
#
#
# ────────────────────────────────────────────────────────────────────
#   Judge mode: reference
#   Default prompt: P1 — concise label (5-15 words)
#
#   Each request:
#     1. Enter a ticket file path (or press Enter to repeat last file)
#     2. Select a prompt (or press Enter to keep current)
#   Type 'exit' to stop.
#
# Ticket file >>> /content/test_tickets.txt
#   3 tickets loaded from test_tickets.txt
#
#   Prompts:
#     P1: concise label (5-15 words) ◄ current
#     P2: primary issue in one phrase
#     P3: knowledge base category name
#     P4: common theme description
#     P5: chatbot routing label
#   Select prompt [P1]:
#
# [Request #1 | Prompt P1: concise label (5-15 words)]
# 18:46:42 | WARNING  | phase1.labeling.frontier_llm | [labeling] Anthropic SDK rejected param 'temperature' (SDK v1.6.0) — removing and retrying.
# 18:46:42 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# Both `max_new_tokens` (=60) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   Scoring ... (calls judge LLM)
# Batches: 100% 1/1 [00:00<00:00,  5.83it/s]
# Batches: 100% 1/1 [00:00<00:00, 63.95it/s]
# 18:46:46 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:46:47 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# Batches: 100% 1/1 [00:00<00:00, 81.49it/s]
# Batches: 100% 1/1 [00:00<00:00, 77.79it/s]
# 18:46:47 | WARNING  | phase1.evaluation.llm_judge | [llm_judge] Anthropic SDK rejected param 'temperature' — removing and retrying.
# 18:46:50 | INFO     | httpx2 | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
#
# ====================================================================
#   RESULTS — Prompt P1
# ────────────────────────────────────────────────────────────────────
#   Input tickets (3):
#     1. I forgot my account PIN and cannot access my account.
#     2. I need to reset my PIN to log back into my account.
#     3. My PIN isn't working and I'm locked out of my account.
#
# ────────────────────────────────────────────────────────────────────  GENERATED LABELS
# ╭───────────────────────────┬────────────┬──────────────────────────╮
# │ Model                     │ Label      │ Latency                  │
# ├───────────────────────────┼────────────┼──────────────────────────┤
# │ Teacher LLM (ceiling)     │ Account PIN Reset and Access
# Recovery            │ 1.46s                    │
# │ SLM Baseline (pre-distil) │ Cluster 1: Account PIN, PIN
# reset, account locked            │ 2.59s  ← generation only │
# │ SLM Fine-tuned (post-
# distil)                           │ Locked Out │ 0.48s  ← generation only │
# ╰───────────────────────────┴────────────┴──────────────────────────╯
#
# ────────────────────────────────────────────────────────────────────  QUALITY SCORES (vs Teacher label)
# ╭────────────────┬──────────┬───────────┬───────────────┬─────────────┬──────────┬───────────╮
# │ Model          │ Cosine   │ ROUGE-L   │ Faithful.     │   Specific. │   Equiv. │   Comp./5 │
# ├────────────────┼──────────┼───────────┼───────────────┼─────────────┼──────────┼───────────┤
# │ Teacher LLM    │ —        │ —         │ 5 (self-eval) │           5 │        5 │         5 │
# │ SLM Baseline   │ 0.621    │ 0.429     │ 4             │           2 │        2 │         0 │
# │ SLM Fine-tuned │ 0.373    │ 0.000     │ 3             │           2 │        2 │         0 │
# ╰────────────────┴──────────┴───────────┴───────────────┴─────────────┴──────────┴───────────╯
#
# ────────────────────────────────────────────────────────────────────  JUDGE REASONING
#   Baseline: The candidate label accurately captures the content (PIN reset, account access issues) but is poorly formatted as a list of keywords rather than a coherent label, lacks the contextual framing of 'recovery' or 'reset', and is too vague/technical compared to the reference's clear problem-solution structure.
#   Fine-tuned: The candidate label captures part of the issue (being locked out) but misses the core resolution path (PIN reset) and is too vague to distinguish this cluster from other account access problems.
# ====================================================================
#
# Ticket file >>>
# Interrupted. Exiting demo.
#
# Session ended.  1 inference request(s) processed.

# %%
# ── Push code changes to GitHub ───────────────────────────────────────────────
import subprocess, os

MSG = 'describe your changes'   # ← UPDATE
REPO = '/content/project'

for cmd in [['git','add','.'], ['git','commit','-m',MSG], ['git','push']]:
    r = subprocess.run(cmd, capture_output=True, text=True, cwd=REPO)
    out = (r.stdout + r.stderr).strip()
    if out:
        print(out)
print('Done')

# %% [markdown]
# ---
# ## First session only — create your branch
#
# Only needed if your branch does not yet exist on GitHub.

# %%
# ── Create branch on GitHub (run ONCE) ───────────────────────────────────────
import subprocess

MY_BRANCH = 'pair-X/model-name'   # ← CHANGE THIS

for cmd in [
    ['git', 'checkout', '-b', MY_BRANCH],
    ['git', 'push', '-u', 'origin', MY_BRANCH],
]:
    r = subprocess.run(cmd, capture_output=True, text=True, cwd='/content/project')
    print((r.stdout + r.stderr).strip())

print(f"\n✅ Branch '{MY_BRANCH}' created.")
print(f"Change BRANCH_NAME in Cell 3 to '{MY_BRANCH}' for all future sessions.")
